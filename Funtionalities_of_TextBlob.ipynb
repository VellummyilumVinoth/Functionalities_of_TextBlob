# %% [markdown]
# <a href="https://colab.research.google.com/github/VellummyilumVinoth/Functionalities_of_TextBlob/blob/main/Funtionalities_of_TextBlob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # What is TextBlob
#
#
# *   TextBlob is an open-source python library used to perform NLP activities like Lemmatization, Stemming, Tokeneization, Noun Phrase Extraction, POS, Tagging, N-Grams, Sentimental Analysis.
# *   It is faster than NLTK, however it does not provide the functionalities like vectorization, dependency parsing.
# *   Text Classification, Sentiment Analysis can be performed using TextBlob.
# *   Installation: pip install textblob

# %%
# Install TextBlob
# !pip install nltk
# !pip install textblob
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk
nltk.download("averaged_perceptron_tagger")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ## Functionalities of Textblob
#
#
# *   Language Detection
# *   Word Correction
# *   Word Count
